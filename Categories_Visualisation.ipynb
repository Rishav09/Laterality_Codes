# %%
import pandas as pd

# %%
master_path = '/home/iscreen/Sierra/Master_Daddy_Project/Laterality/Stage_files/Split_Final_Staged_Files/total_laterality_master_file.csv'
df_master = pd.read_csv(master_path)
df_master
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      169814_1085325.jpg              0               0         0      1
# 1      169814_1085328.jpg              0               0         0      1
# 2      169855_1085382.jpg              0               0         1      0
# 3      169855_1085384.jpg              0               0         0      1
# 4      169855_1085388.jpg              0               0         0      1
# ...                   ...            ...             ...       ...    ...
# 94863  279218_1871173.jpg              0               0         0      1
# 94864  279385_1872264.jpg              0               0         1      0
# 94865  279413_1872492.jpg              0               0         0      1
# 94866  279413_1872493.jpg              0               0         0      1
# 94867  279445_1872749.jpg              0               0         1      0
#
#        Canon_Left  Canon_Right Grader New_Extension  labels
# ...

# %%
random_samples = df_master.groupby('labels').apply(lambda x: x.sample(n=2, random_state=42))
random_samples
# Out:
#                              img  Interior_Left  Interior_Right  Exterior  \
# labels
# 0      48472  291398_1961662.jpg              1               0         0
#        9281   241359_1588841.jpg              1               0         0
# 1      24557  176313_1127883.jpg              0               1         0
#        33221  243753_1605794.jpg              0               1         0
# 2      14362  277545_1858707.jpg              0               0         1
#        36380  266075_1769464.jpg              0               0         1
# 3      7866   230626_1517624.jpg              0               0         0
#        27859  203825_1323932.jpg              0               0         0
# 4      81307  331224_2274275.jpg              0               0         0
#        37951  278405_1865062.jpg              0               0         0
# 5      15935  289217_1944825.jpg              0               0         0
#        81436  332110_2280789.jpg              0               0         0
# ...

# %%
source_folder = '/home/iscreen/data_division/Stage_Data/'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import display

# %%
n_rows = 2
n_columns = 6
n_images = n_rows * n_columns
assert len(random_samples) >= n_images
def display_image(image_paths, label, pos):
    image_path = os.path.join(source_folder, image_paths)
    img = mpimg.imread(image_path)
    ax = plt.subplot(n_rows, n_columns, pos)
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(label)

# %%
label_mapping = {
    0: 'Interior Left',
    1: 'Interior Right',
    2: 'Exterior',
    3: 'Canon Left',
    4:'Canon Right',
    5:'Other'
    # Add more mappings as needed
}

# %%
random_samples['updated_label'] = random_samples['labels'].map(label_mapping)

# %%
import os
width_per_image = 4
height_per_image = 4

plt.figure(figsize=(n_columns * width_per_image, n_rows * height_per_image))


for index, (img_path, label) in enumerate(zip(random_samples['img'], random_samples['updated_label'])):
    display_image(img_path, label, index+1)

plt.tight_layout()
plt.show()

# %%
# !pip install matplotlib
# Out:
# /bin/bash: /home/iscreen/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 25.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 30.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 31.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.1 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.3/300.3 kB 24.8 MB/s eta 0:00:00
# ...
