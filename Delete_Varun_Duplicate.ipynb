# %%
## Varun's file had duplicate elements so I had to delete  them- 331 and save them

# %%
import pandas as pd
path = '/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_binary.csv'
df_input = pd.read_csv(path, engine='python').iloc[:, :]
#df_input = df_input.sample(frac=1, random_state=44)

df_input
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      169867_1085472.JPG              0               1         0      0
# 1      169867_1085477.JPG              1               0         0      0
# 2      169883_1085597.JPG              0               1         0      0
# 3      169883_1085599.JPG              0               1         0      0
# 4      169883_1085602.JPG              1               0         0      0
# ...                   ...            ...             ...       ...    ...
# 11728  193315_1246082.JPG              0               1         0      0
# 11729  198783_1286282.JPG              0               1         0      0
# 11730  233023_1533571.JPG              1               0         0      0
# 11731  268017_1785608.jpg              1               0         0      0
# 11732  268017_1785609.jpg              0               1         0      0
#
#        Canon_Left  Canon_Right Grader  Unsure  labels
# ...

# %%
df_binary = df_input.drop_duplicates()

# %%
df_binary
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      169867_1085472.JPG              0               1         0      0
# 1      169867_1085477.JPG              1               0         0      0
# 2      169883_1085597.JPG              0               1         0      0
# 3      169883_1085599.JPG              0               1         0      0
# 4      169883_1085602.JPG              1               0         0      0
# ...                   ...            ...             ...       ...    ...
# 11728  193315_1246082.JPG              0               1         0      0
# 11729  198783_1286282.JPG              0               1         0      0
# 11730  233023_1533571.JPG              1               0         0      0
# 11731  268017_1785608.jpg              1               0         0      0
# 11732  268017_1785609.jpg              0               1         0      0
#
#        Canon_Left  Canon_Right Grader  Unsure  labels
# ...

# %%
canon_path = '/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_canon_binary.csv'
canon_input = pd.read_csv(canon_path, engine='python').iloc[:, :]
canon_input
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      169866_1085465.JPG              0               0         0      0
# 1      169919_1085900.JPG              0               0         0      0
# 2      169941_1086059.JPG              0               0         0      0
# 3      170206_1087720.jpg              0               0         0      0
# 4      170239_1087952.jpg              0               0         0      0
# ...                   ...            ...             ...       ...    ...
# 16826  267643_1782490.JPG              0               0         0      0
# 16827  270631_1805560.jpg              0               0         0      0
# 16828  277510_1858434.JPG              0               0         0      0
# 16829  277948_1883378.JPG              0               0         0      0
# 16830  277962_1861315.JPG              0               0         0      0
#
#        Canon_Left  Canon_Right Grader  Unsure  labels
# ...

# %%
df_canon_binary = canon_input.drop_duplicates()
df_canon_binary
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      169866_1085465.JPG              0               0         0      0
# 1      169919_1085900.JPG              0               0         0      0
# 2      169941_1086059.JPG              0               0         0      0
# 3      170206_1087720.jpg              0               0         0      0
# 4      170239_1087952.jpg              0               0         0      0
# ...                   ...            ...             ...       ...    ...
# 16826  267643_1782490.JPG              0               0         0      0
# 16827  270631_1805560.jpg              0               0         0      0
# 16828  277510_1858434.JPG              0               0         0      0
# 16829  277948_1883378.JPG              0               0         0      0
# 16830  277962_1861315.JPG              0               0         0      0
#
#        Canon_Left  Canon_Right Grader  Unsure  labels
# ...

# %%
pent_path = '/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_pent.csv'
df_pent_input = pd.read_csv(pent_path, engine='python').iloc[:, :]
df_pent_mod = df_pent_input.drop_duplicates()
df_pent_mod
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      169814_1085325.JPG              0               0         0      1
# 1      169814_1085328.JPG              0               0         0      1
# 2      169855_1085384.jpg              0               0         0      1
# 3      169855_1085388.jpg              0               0         0      1
# 4      169855_1085389.jpg              0               0         0      1
# ...                   ...            ...             ...       ...    ...
# 74182  278322_1864351.JPG              0               0         0      1
# 74183  278808_1868223.jpg              0               0         0      1
# 74184  279218_1871173.JPG              0               0         0      1
# 74185  279413_1872492.jpg              0               0         0      1
# 74186  279413_1872493.jpg              0               0         0      1
#
#        Canon_Left  Canon_Right Grader  Unsure  labels
# ...

# %%
quad_path = '/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_quad.csv'
df_quad_input = pd.read_csv(quad_path, engine='python').iloc[:, :]
df_quad_mod = df_quad_input.drop_duplicates()
df_quad_mod
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      169866_1085465.JPG              0               0         0      0
# 1      169867_1085472.JPG              0               1         0      0
# 2      169867_1085477.JPG              1               0         0      0
# 3      169883_1085597.JPG              0               1         0      0
# 4      169883_1085599.JPG              0               1         0      0
# ...                   ...            ...             ...       ...    ...
# 28557  268017_1785609.jpg              0               1         0      0
# 28558  270631_1805560.jpg              0               0         0      0
# 28559  277510_1858434.JPG              0               0         0      0
# 28560  277948_1883378.JPG              0               0         0      0
# 28561  277962_1861315.JPG              0               0         0      0
#
#        Canon_Left  Canon_Right Grader  Unsure  labels
# ...

# %%
df_binary.to_csv("/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_binary.csv", index=False)

# %%
path = '/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_binary.csv'
new_df_input = pd.read_csv(path, engine='python').iloc[:, :]
new_df_input
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      169867_1085472.JPG              0               1         0      0
# 1      169867_1085477.JPG              1               0         0      0
# 2      169883_1085597.JPG              0               1         0      0
# 3      169883_1085599.JPG              0               1         0      0
# 4      169883_1085602.JPG              1               0         0      0
# ...                   ...            ...             ...       ...    ...
# 11397  193315_1246082.JPG              0               1         0      0
# 11398  198783_1286282.JPG              0               1         0      0
# 11399  233023_1533571.JPG              1               0         0      0
# 11400  268017_1785608.jpg              1               0         0      0
# 11401  268017_1785609.jpg              0               1         0      0
#
#        Canon_Left  Canon_Right Grader  Unsure  labels
# ...

# %%
df_binary.to_csv("/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_binary.csv", index=False)
df_canon_binary.to_csv("/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_canon_binary.csv", index=False)
df_pent_mod.to_csv("/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_pent.csv", index=False)

# %%
df_quad_mod.to_csv("/Users/swastik/ophthalmology/Daddy_Project/Laterality/Stage_files/laterality_labels_quad.csv", index=False)

# %%
## How I found those are duplicates

# %%
duplicates_mask = df_input.duplicated()
duplicates = df_input[duplicates_mask]
print(duplicates)
# Out:
#                      img  Interior_Left  Interior_Right  Exterior  Other  \
# 8576  258597_1716468.JPG              0               1         0      0
# 8577  258630_1716722.JPG              0               1         0      0
# 8578  258630_1716727.JPG              1               0         0      0
# 8579  258630_1716729.JPG              1               0         0      0
# 8580  258646_1717537.JPG              0               1         0      0
# ...                  ...            ...             ...       ...    ...
# 8942  273589_1828642.JPG              0               1         0      0
# 8943  273600_1828744.JPG              1               0         0      0
# 8944  273609_1828818.JPG              0               1         0      0
# 8945  273613_1828863.JPG              1               0         0      0
# 8946  273646_1829138.JPG              1               0         0      0
#
#       Canon_Left  Canon_Right Grader  Unsure  labels
# ...

# %%
duplicates['Grader'].value_counts()
# Out:
# Varun    331
# Name: Grader, dtype: int64
