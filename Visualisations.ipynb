# %%
import pandas as pd

# %%
df_train = pd.read_csv("/Users/swastik/ophthalmology/Master_Daddy_Project/Laterality/Stage_files/Split_Final_Staged_Files/Total_Equal_Split/total_laterality_train_2023-03-30_17-42-47.csv")
df_train
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      181481_1161659.jpg              0               0         0      1
# 1      313152_2133751.jpg              0               0         0      1
# 2      189275_1215650.jpg              0               0         0      1
# 3      325402_2229298.jpg              0               0         0      1
# 4      278795_1868121.jpg              0               0         0      1
# ...                   ...            ...             ...       ...    ...
# 75891  219491_1437074.jpg              0               0         1      0
# 75892    67126_316387.jpg              0               0         0      1
# 75893  301296_2039105.jpg              0               0         1      0
# 75894  177979_1137436.jpg              0               0         1      0
# 75895  288512_1938978.jpg              0               0         0      1
#
#        Canon_Left  Canon_Right   Grader New_Extension  labels
# ...

# %%
interior_left = df_train['Interior_Left'].sum()
interior_right = df_train['Interior_Right'].sum()
canon_left = df_train['Canon_Left'].sum()
canon_right = df_train['Canon_Right'].sum()
other = df_train['Other'].sum()
exterior = df_train['Exterior'].sum()

# %%
df_sum_train = pd.DataFrame({'interior_right':[interior_right],'interior_left':[interior_left],'canon_left':[canon_left],'canon_right':[canon_right],'other':[other],'exterior':[exterior]})
df_sum_train
# Out:
#    interior_right  interior_left  canon_left  canon_right  other  exterior
# 0            2011           3017        4909         4831  41905     19223

# %%
import matplotlib.pyplot as plt
ax = df_sum_train.plot.bar(rot=0)
# Add labels to the bars
for p in ax.containers:
    ax.bar_label(p, label_type='edge')
plt.show()

# %%
df_valid = pd.read_csv("/Users/swastik/ophthalmology/Master_Daddy_Project/Laterality/Stage_files/Split_Final_Staged_Files/Total_Equal_Split/total_laterality_valid_2023-03-30_17-42-47.csv")
df_valid
# Out:
#                      img  Interior_Left  Interior_Right  Exterior  Other  \
# 0     177938_1137094.jpg              0               0         1      0
# 1     190125_1222200.jpg              0               0         1      0
# 2     261144_1735151.jpg              0               0         0      0
# 3     221568_1451736.jpg              0               1         0      0
# 4     207414_1349900.jpg              0               0         0      1
# ...                  ...            ...             ...       ...    ...
# 9481  178023_1137709.jpg              0               0         0      1
# 9482  300683_2033937.jpg              0               0         1      0
# 9483  299026_2021033.jpg              0               0         0      1
# 9484  270391_1803577.jpg              0               0         0      0
# 9485  246725_1628413.jpg              0               0         0      0
#
#       Canon_Left  Canon_Right   Grader New_Extension  labels
# ...

# %%
df_test = pd.read_csv("/Users/swastik/ophthalmology/Master_Daddy_Project/Laterality/Stage_files/Split_Final_Staged_Files/Total_Equal_Split/total_laterality_test_2023-03-30_17-42-47.csv")
df_test
# Out:
#                      img  Interior_Left  Interior_Right  Exterior  Other  \
# 0     242129_1594784.jpg              0               0         0      1
# 1     309723_2106415.jpg              0               0         1      0
# 2     197323_1275028.jpg              1               0         0      0
# 3     254968_1689679.jpg              0               0         1      0
# 4     193791_1249683.jpg              0               0         0      0
# ...                  ...            ...             ...       ...    ...
# 9481  171233_1094044.jpg              0               0         0      0
# 9482  229956_1512385.jpg              0               0         0      0
# 9483  222409_1458271.jpg              0               1         0      0
# 9484    65522_305325.jpg              0               0         0      0
# 9485  208521_1358355.jpg              0               0         0      1
#
#       Canon_Left  Canon_Right   Grader New_Extension  labels
# ...

# %%
interior_left = df_valid['Interior_Left'].sum()
interior_right = df_valid['Interior_Right'].sum()
canon_left = df_valid['Canon_Left'].sum()
canon_right = df_valid['Canon_Right'].sum()
other = df_valid['Other'].sum()
exterior = df_valid['Exterior'].sum()

# %%
df_sum_valid = pd.DataFrame({'interior_right':[interior_right],'interior_left':[interior_left],'canon_left':[canon_left],'canon_right':[canon_right],'other':[other],'exterior':[exterior]})
df_sum_valid
# Out:
#    interior_right  interior_left  canon_left  canon_right  other  exterior
# 0            1581           1581        1581         1581   1581      1581

# %%
import matplotlib.pyplot as plt
ax = df_sum_valid.plot.bar(rot=0)
# Add labels to the bars
for p in ax.containers:
    ax.bar_label(p, label_type='edge')
plt.show()

# %% [markdown]
# ## Now for stratified Split

# %%
df1_train = pd.read_csv("/Users/swastik/ophthalmology/Master_Daddy_Project/Laterality/Stage_files/Split_Final_Staged_Files/Stratified_Equal_Split/total_stratified_laterality_train_2023-03-31_17-27-51.csv")
df1_train
# Out:
#                       img  Interior_Left  Interior_Right  Exterior  Other  \
# 0      243196_1601976.jpg              0               0         1      0
# 1      317443_2167746.jpg              0               0         0      1
# 2      309866_2107483.jpg              0               0         0      1
# 3      273058_1824240.jpg              0               0         0      1
# 4      234059_1540643.jpg              1               0         0      0
# ...                   ...            ...             ...       ...    ...
# 75889  221435_1450684.jpg              0               0         0      1
# 75890  241151_1587170.jpg              0               0         1      0
# 75891  243943_1607286.jpg              0               0         0      0
# 75892  261646_1739052.jpg              0               0         0      0
# 75893  258081_1712725.jpg              0               0         0      1
#
#        Canon_Left  Canon_Right   Grader New_Extension  labels
# ...

# %%
interior_left = df1_train['Interior_Left'].sum()
interior_right = df1_train['Interior_Right'].sum()
canon_left = df1_train['Canon_Left'].sum()
canon_right = df1_train['Canon_Right'].sum()
other = df1_train['Other'].sum()
exterior = df1_train['Exterior'].sum()

# %%
df_sum_train = pd.DataFrame({'interior_right':[interior_right],'interior_left':[interior_left],'canon_left':[canon_left],'canon_right':[canon_right],'other':[other],'exterior':[exterior]})
df_sum_train
# Out:
#    interior_right  interior_left  canon_left  canon_right  other  exterior
# 0            4138           4943        6457         6394  36054     17908

# %%
import matplotlib.pyplot as plt
ax = df_sum_train.plot.bar(rot=0)
# Add labels to the bars
for p in ax.containers:
    ax.bar_label(p, label_type='edge')
plt.show()

# %%
df1_valid = pd.read_csv("/Users/swastik/ophthalmology/Master_Daddy_Project/Laterality/Stage_files/Split_Final_Staged_Files/Stratified_Equal_Split/total_stratified_laterality_valid_2023-03-31_17-27-51.csv")
df1_valid
# Out:
#                      img  Interior_Left  Interior_Right  Exterior  Other  \
# 0     199203_1289511.jpg              0               0         0      1
# 1     231051_1520351.jpg              0               0         1      0
# 2     319883_2187348.jpg              0               0         1      0
# 3     233774_1539191.jpg              0               0         0      1
# 4     243020_1600984.jpg              0               0         1      0
# ...                  ...            ...             ...       ...    ...
# 9482  195731_1263787.jpg              0               0         0      1
# 9483  238259_1567193.jpg              0               0         0      0
# 9484  320230_2189625.jpg              0               0         0      1
# 9485  250753_1657598.jpg              0               0         0      1
# 9486  225936_1484417.jpg              0               0         0      1
#
#       Canon_Left  Canon_Right   Grader New_Extension  labels
# ...

# %%
interior_left = df1_valid['Interior_Left'].sum()
interior_right = df1_valid['Interior_Right'].sum()
canon_left = df1_valid['Canon_Left'].sum()
canon_right = df1_valid['Canon_Right'].sum()
other = df1_valid['Other'].sum()
exterior = df1_valid['Exterior'].sum()

# %%
df_sum_train = pd.DataFrame({'interior_right':[interior_right],'interior_left':[interior_left],'canon_left':[canon_left],'canon_right':[canon_right],'other':[other],'exterior':[exterior]})
df_sum_train
# Out:
#    interior_right  interior_left  canon_left  canon_right  other  exterior
# 0             517            618         807          799   4507      2239

# %%
import matplotlib.pyplot as plt
ax = df_sum_train.plot.bar(rot=0)
# Add labels to the bars
for p in ax.containers:
    ax.bar_label(p, label_type='edge')
plt.show()

# %%
df1_test = pd.read_csv("/Users/swastik/ophthalmology/Master_Daddy_Project/Laterality/Stage_files/Split_Final_Staged_Files/Stratified_Equal_Split/total_stratified_laterality_test_2023-03-31_17-27-51.csv")
df1_test
# Out:
#                      img  Interior_Left  Interior_Right  Exterior  Other  \
# 0     181332_1160864.jpg              0               0         0      0
# 1     318037_2172568.jpg              0               1         0      0
# 2     192969_1243366.jpg              0               0         0      0
# 3     234053_1540599.jpg              1               0         0      0
# 4     188183_1207352.jpg              0               0         0      1
# ...                  ...            ...             ...       ...    ...
# 9482  307661_2089846.jpg              0               0         0      1
# 9483  291406_1961723.jpg              0               0         1      0
# 9484  322904_2210493.jpg              0               0         0      1
# 9485  314954_2148168.jpg              0               0         0      1
# 9486  191487_1232300.jpg              0               0         0      0
#
#       Canon_Left  Canon_Right   Grader New_Extension  labels
# ...

# %%
interior_left = df1_test['Interior_Left'].sum()
interior_right = df1_test['Interior_Right'].sum()
canon_left = df1_test['Canon_Left'].sum()
canon_right = df1_test['Canon_Right'].sum()
other = df1_test['Other'].sum()
exterior = df1_test['Exterior'].sum()

# %%
df_sum_train = pd.DataFrame({'interior_right':[interior_right],'interior_left':[interior_left],'canon_left':[canon_left],'canon_right':[canon_right],'other':[other],'exterior':[exterior]})
df_sum_train
# Out:
#    interior_right  interior_left  canon_left  canon_right  other  exterior
# 0             518            618         807          800   4506      2238

# %%
import matplotlib.pyplot as plt
ax = df_sum_train.plot.bar(rot=0)
# Add labels to the bars
for p in ax.containers:
    ax.bar_label(p, label_type='edge')
plt.show()
