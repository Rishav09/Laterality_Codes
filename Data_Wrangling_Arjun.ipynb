# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/swastik/ophthalmology/Daddy_Project/Laterality/Data_Staging/Input_files/assigned_classes_Arjun.csv')
df
# Out:
#                      img  other  external  canon_OD  canon_OS  left_internal  \
# 0     275347_1841447.JPG      0         0         0         0              0
# 1     275953_1846181.JPG      1         0         0         0              0
# 2     276001_1846612.JPG      1         0         0         0              0
# 3     275738_1844635.JPG      0         0         0         1              0
# 4     276575_1851317.JPG      0         0         0         1              0
# ...                  ...    ...       ...       ...       ...            ...
# 2995  279218_1871173.JPG      1         0         0         0              0
# 2996  279385_1872264.JPG      0         1         0         0              0
# 2997  279413_1872492.jpg      1         0         0         0              0
# 2998  279413_1872493.jpg      1         0         0         0              0
# 2999  279445_1872749.jpg      0         1         0         0              0
#
#       right_internal
# 0                  1
# ...

# %%
df.rename(columns={'other':'Other','external':"Exterior","right_internal":"Interior_Right","left_internal":"Interior_Left","canon_OS":"Canon_Left","canon_OD":"Canon_Right"}, inplace=True)
df
# Out:
#                      img  Other  Exterior  Canon_Right  Canon_Left  \
# 0     275347_1841447.JPG      0         0            0           0
# 1     275953_1846181.JPG      1         0            0           0
# 2     276001_1846612.JPG      1         0            0           0
# 3     275738_1844635.JPG      0         0            0           1
# 4     276575_1851317.JPG      0         0            0           1
# ...                  ...    ...       ...          ...         ...
# 2995  279218_1871173.JPG      1         0            0           0
# 2996  279385_1872264.JPG      0         1            0           0
# 2997  279413_1872492.jpg      1         0            0           0
# 2998  279413_1872493.jpg      1         0            0           0
# 2999  279445_1872749.jpg      0         1            0           0
#
#       Interior_Left  Interior_Right
# 0                 0               1
# 1                 0               0
# 2                 0               0
# ...

# %%
df['Grader'] = 'Arjun'
df
# Out:
#                      img  Other  Exterior  Canon_Right  Canon_Left  \
# 0     275347_1841447.JPG      0         0            0           0
# 1     275953_1846181.JPG      1         0            0           0
# 2     276001_1846612.JPG      1         0            0           0
# 3     275738_1844635.JPG      0         0            0           1
# 4     276575_1851317.JPG      0         0            0           1
# ...                  ...    ...       ...          ...         ...
# 2995  279218_1871173.JPG      1         0            0           0
# 2996  279385_1872264.JPG      0         1            0           0
# 2997  279413_1872492.jpg      1         0            0           0
# 2998  279413_1872493.jpg      1         0            0           0
# 2999  279445_1872749.jpg      0         1            0           0
#
#       Interior_Left  Interior_Right Grader
# 0                 0               1  Arjun
# 1                 0               0  Arjun
# ...

# %%
df['Other'].sum()
# Out:
# 1960

# %%
df['Exterior'].sum()
# Out:
# 724

# %%
df['Canon_Right'].sum()
# Out:
# 87

# %%
df['Canon_Left'].sum()
# Out:
# 115

# %%
df['Interior_Left'].sum()
# Out:
# 58

# %%
df['Interior_Right'].sum()
# Out:
# 56

# %%
df.to_csv("/Users/swastik/ophthalmology/Daddy_Project/Laterality/Data_Staging/Input_files/total_Arjun.csv")
